# %% [markdown]
# # BigQuery Getting Started
#
# ### Installing bq console
#
# ```bash
# $ echo "deb [signed-by=/usr/share/keyrings/cloud.google.gpg] https://packages.cloud.google.com/apt cloud-sdk main" | sudo tee -a /etc/apt/sources.list.d/google-cloud-sdk.list
# $ sudo apt-get install apt-transport-https ca-certificates gnupg
# $ curl https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo apt-key --keyring /usr/share/keyrings/cloud.google.gpg add -
# $ sudo apt-get update && sudo apt-get install google-cloud-sdk
#
# $ gcloud init --console-only
# Your current configuration has been set to: [default]
#
# You must log in to continue. Would you like to log in (Y/n)?Y
#
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?code_challenge=2323
#
# Enter verification code: 32kl;22l
# You are logged in as: [johannes@fluquid.com].
#
# Pick cloud project to use:
#  [1] asdf-123233
#  [6] Create a new project
# Please enter numeric choice or text value (must exactly match list
# item):  1
#
# Your current project has been set to: [asdf-123233].
#
# * Run `gcloud --help` to see the Cloud Platform services you can interact with. And run `gcloud help COMMAND` to get help on any gcloud command.
# ```

# %%
# %%time
# !bq query --use_legacy_sql=false 'SELECT sum(size_bytes)/pow(10,12) as size_tb FROM `gdelt-bq:gdeltv2.__TABLES__`;'
# Out:
# Waiting on bqjob_r70a7e05e807903c5_0000016eb157f833_1 ... (0s) Current status: DONE
# +-----------------+
# |     size_tb     |
# +-----------------+
# | 79.526084032165 |
# +-----------------+
# CPU times: user 125 ms, sys: 109 ms, total: 234 ms
# Wall time: 11.7 s

# %% [markdown]
# ## Jupyter bigquery extension
#
# * setup authentication: https://console.cloud.google.com/apis/credentials/serviceaccountkey
# * `export GOOGLE_APPLICATION_CREDENTIALS="/home/user/Downloads/[FILE_NAME].json"`

# %%
# %load_ext google.cloud.bigquery
import google.cloud.bigquery.magics

# use bqstorage for large query results
google.cloud.bigquery.magics.context.use_bqstorage_api = True

# %%
# %%bigquery
# SELECT name
#     FROM `bigquery-public-data.usa_names.usa_1910_current`
#     WHERE state = 'TX'
#     LIMIT 5
# Out:
#      name
# 0    Mary
# 1    Ruby
# 2   Annie
# 3  Willie
# 4    Ruth

# %% [markdown]
# ## Pandas integration

# %%
import pandas

sql = """
    SELECT name
    FROM `bigquery-public-data.usa_names.usa_1910_current`
    WHERE state = 'TX'
    LIMIT 5
"""

pandas.read_gbq(sql, dialect='standard', use_bqstorage_api=True)
# Out:
# Downloading: 100%|██████████| 5/5 [00:01<00:00,  2.70rows/s]
#      name
# 0    Mary
# 1    Ruby
# 2   Annie
# 3  Willie
# 4    Ruth

# %%
from google.cloud import bigquery

client = bigquery.Client()
client.query(sql).to_dataframe()
# Out:
#      name
# 0    Mary
# 1    Ruby
# 2   Annie
# 3  Willie
# 4    Ruth

# %% [markdown]
# ### Inserting tables from Pandas

# %%
'''
table_id = 'my_dataset.new_table'
df.to_gbq(table_id)
'''
None

# %% [markdown]
# ### ODBC/ JDBC

# %%
import pyodbc

if False:
    cnxn = pyodbc.connect('DRIVER={CData ODBC Driver for GoogleBigQuery};OAuthAccessToken=MyOAuthAccessToken;ProjectId=NameOfProject;DatasetId=NameOfDataset')
    cnxn = pyodbc.connect('DSN=CData GoogleBigQuery Source Sys;User=MyUser;Password=MyPassword')
    cursor = cnxn.cursor()
    cursor.execute("SELECT actor.attributes.email, repository.name FROM publicdata:samples.github_nested WHERE repository.name = 'EntityFramework'")
    rows = cursor.fetchall()
    for row in rows:
        print(row.actor.attributes.email, row.repository.name)

# %% [markdown]
# ## Ibis Framework
#
# Ibis allows you to run the same query against different backends:
# - Apache Impala
# - Apache Kudu]
# - PostgreSQL
# - SQLite
# - Yandex ClickHouse
# - Pandas
# - Google BigQuery
#
# ("starter code" by https://cloud.google.com/community/tutorials/bigquery-ibis ;)

# %%
import ibis
conn = ibis.bigquery.connect(
    project_id='asdf-167312',
    dataset_id='bigquery-public-data.stackoverflow')

# %%
table = conn.table('posts_questions')
table
# Out:
# BigQueryTable[table]
#   name: bigquery-public-data.stackoverflow.posts_questions
#   schema:
#     id : int64
#     title : string
#     body : string
#     accepted_answer_id : int64
#     answer_count : int64
#     comment_count : int64
#     community_owned_date : timestamp
#     creation_date : timestamp
#     favorite_count : int64
#     last_activity_date : timestamp
#     last_edit_date : timestamp
#     last_editor_display_name : string
#     last_editor_user_id : int64
#     owner_display_name : string
#     owner_user_id : int64
#     parent_id : string
#     post_type_id : int64
#     score : int64
#     tags : string
#     view_count : int64

# %%
def percentage_answered(proj):
    has_answer_int = (proj.answer_count > 0).ifelse(1, 0)
    return has_answer_int.mean() * 100

expression = (
    table['creation_date', 'answer_count']
    .mutate(year=lambda x: x.creation_date.year())
    .groupby('year')
    .aggregate(
        total_questions=lambda x: x.count(),
        percentage_answered=percentage_answered,
    )
    .sort_by(ibis.desc(lambda x: x.year))
)

expression.execute()
# Out:
#     year  percentage_answered  total_questions
# 0   2019            66.506422          1440718
# 1   2018            77.212207          2008571
# 2   2017            83.040260          2132515
# 3   2016            84.753614          2215666
# 4   2015            86.500011          2211624
# 5   2014            88.606067          2157464
# 6   2013            91.688398          2054622
# 7   2012            94.583315          1641742
# 8   2011            97.189186          1197767
# 9   2010            99.044867           692888
# 10  2009            99.642129           342861
# 11  2008            99.879425            58055

# %% [markdown]
# ## User Defined Functions (UDF)

# %%
import ibis.expr.datatypes as dt
from ibis.bigquery import udf

@udf(['double'], 'double')
def example_udf(value):
    return value + 1.0

test_column = ibis.literal(1, type='double')
expression = example_udf(test_column)

print(conn.execute(expression))
# Out:
# 2.0

# %% [markdown]
# ## Joins
#
# Joining literacy rate with country details

# %%
edu_table = conn.table(
    'international_education',
    database='bigquery-public-data.world_bank_intl_education')
edu_table = edu_table['value', 'year', 'country_code', 'indicator_code']

country_table = conn.table(
    'country_code_iso',
    database='bigquery-public-data.utility_us')
country_table = country_table['country_name', 'alpha_3_code']

expression = edu_table.join(
    country_table,
    [edu_table.country_code == country_table.alpha_3_code])

conn.execute(
    expression[edu_table.year == 2016]
        # Adult literacy rate.
        [edu_table.indicator_code == 'SE.ADT.LITR.ZS']
        .sort_by([ibis.desc(edu_table.value)])
        .limit(20)
)
# Out:
#         value  year country_code  indicator_code  \
# 0   100.00000  2016          AND  SE.ADT.LITR.ZS
# 1    99.79006  2016          AZE  SE.ADT.LITR.ZS
# 2    98.84151  2016          SRB  SE.ADT.LITR.ZS
# 3    98.25051  2016          ESP  SE.ADT.LITR.ZS
# 4    97.12709  2016          VEN  SE.ADT.LITR.ZS
# 5    97.04959  2016          SGP  SE.ADT.LITR.ZS
# 6    96.93023  2016          PSE  SE.ADT.LITR.ZS
# 7    96.93023  2016          PSE  SE.ADT.LITR.ZS
# 8    96.53849  2016          MAC  SE.ADT.LITR.ZS
# 9    95.37697  2016          IDN  SE.ADT.LITR.ZS
# 10   94.35023  2016          ECU  SE.ADT.LITR.ZS
# 11   94.17367  2016          PER  SE.ADT.LITR.ZS
# 12   88.98748  2016          HND  SE.ADT.LITR.ZS
# 13   77.04268  2016          COD  SE.ADT.LITR.ZS
# 14   75.55120  2016          MMR  SE.ADT.LITR.ZS
# 15   72.75872  2016          BGD  SE.ADT.LITR.ZS
# 16   22.31155  2016          TCD  SE.ADT.LITR.ZS
#
#                          country_name alpha_3_code
# 0                             Andorra          AND
# 1                          Azerbaijan          AZE
# 2                              Serbia          SRB
# 3                               Spain          ESP
# 4                           Venezuela          VEN
# 5                           Singapore          SGP
# 6                           West Bank          PSE
# 7                          Gaza Strip          PSE
# 8                               Macau          MAC
# 9                           Indonesia          IDN
# 10                            Ecuador          ECU
# 11                               Peru          PER
# 12                           Honduras          HND
# 13  Congo; Democratic Republic of the          COD
# 14                              Burma          MMR
# 15                         Bangladesh          BGD
# 16                               Chad          TCD

# %% [markdown]
# ## Uploading our own data

# %% [markdown]
# - json is not a good choice, especially not if gzip'ed
# - very hard to upload non-compressed data to Google Cloud Storage *argh*
# - twitter sample data is 19GB/ day uncompressed, 2GB/ day compressed
#
# ### Auto-Derive nested schema
# ```bash
# pip install bigquery-schema-generator
#
# zcat twitter-2019-11-24.jl.gz | \
#     generate-schema > twitter.schema.json
# ```
#
# ### Upload data to Google Cloud Storage
# ```bash
# gsutil -h "Content-Type: text/plain" -h "Content-Encoding: gzip" \
#     -m -o GSUtil:parallel_composite_upload_threshold=150M \
#     cp twitter-2019*.gz gs://devfest_twitter/
# ```
#
# ### Load data into BigQuery table
# ```bash
# bq load --source_format NEWLINE_DELIMITED_JSON \
#     --ignore_unknown_values \
#     --schema twitter.schema.json \
#     twitter.tweets \
#     gs://devfest_twitter/sample-2019-11-24.jl.gz
# ```

# %%
# %%bigquery hashtags --use_legacy_sql
# SELECT count(*) as num_ht,
#     count(DISTINCT user.screen_name) as num_users,
#     HOUR(TIMESTAMP(timestamp_ms / 1000)) as hr, entities.hashtags.text as ht
# FROM [asdf-167312.twitter.tweets]
# WHERE entities.hashtags.text IS NOT  null and lang == 'en'
# GROUP BY hr, ht
# HAVING num_ht > 50
# ORDER BY hr ASC, num_ht DESC;

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

hashtags
# Out:
#      num_ht  num_users  hr                                ht
# 0        92         90   2                       NXTTakeOver
# 1        81         66   2                               BTS
# 2        69         67   2                          WarGames
# 3       123        114   3                               BTS
# 4       105        105   3                          MAMAVOTE
# 5        68         63   3                   GOATBlackFriday
# 6        67         63   3                WonhoIsOurStrength
# 7        60         45   3          TwitterEmperorsTHALAFans
# 8        55         54   3                              GOT7
# 9        55         51   3                      나의_모든걸_깨우는_힘
# 10      104         95   4                               BTS
# 11       85         79   4                          MAMAVOTE
# 12       61         53   4                WonhoIsOurStrength
# 13       52         51   4                             방탄소년단
# 14       51         45   4                      나의_모든걸_깨우는_힘
# 15      234        232   5                      WilderOrtiz2
# 16       99         89   5                               BTS
# 17       82         79   5                          MAMAVOTE
# 18       63         63   5           MyFirstParentingMistake
# 19       55         48   5                WonhoIsOurStrength
# 20       93         88   6                               BTS
# 21       85         83   6                          MAMAVOTE
# 22       74         73   6                      WilderOrtiz2
# 23       71         71   6                          JuniusHo
# 24       60         51   6                WonhoIsOurStrength
# 25       55         55   6                             방탄소년단
# 26       55         55   6                              GOT7
# 27      130         96   7          ABeautifuLAYFirstConcert
# 28      113        105   7                               BTS
# 29       95         85   7                          MAMAVOTE
# 30       93         90   7                    MagicShopJapan
# 31       66         48   7             justice_binsachivalay
# 32       65         61   7                              GOT7
# 33       61         60   7                             방탄소년단
# 34       57         57   7                      SEAGames2019
# 35       55         55   7               LaRougeInSeoul_Day1
# 36      149        136   8                               BTS
# 37      143        142   8                              GOT7
# 38      141         92   8  The2wisheverlastingloveinbangkok
# 39      126        123   8                    MagicShopJapan
# 40      105        103   8                             방탄소년단
# 41       95         93   8                                정국
# 42       94         92   8                          MAMAVOTE
# 43       90         89   8                          JUNGKOOK
# 44       90         90   8                               갓세븐
# 45       73         73   8                   GOT7_CallMyName
# 46       68         68   8                    GOT7_니가부르는나의이름
# 47       64         64   8                             IGOT7
# 48       62         62   8                               아가새
# 49       58         42   8             justice_binsachivalay
# 50       57         52   8          ABeautifuLAYFirstConcert
# 51       54         54   8             District9_Unlock_Day2
# 52       51         22   8              50DaysToAVPLEuphoria
# 53      477        459   9                               BTS
# 54      415        409   9                             방탄소년단
# 55      396        391   9                               EXO
# 56      331        330   9                                엑소
# 57      265        229   9               LaRougeInSeoul_Day2
# 58      215        213   9                                정국
# 59      209        207   9                          JUNGKOOK
# 60      168        160   9                          MAMAVOTE
# 61      121        120   9                                RM
# 62      118        115   9                    MagicShopJapan
# 63      114        112   9                                태형
# 64       97         97   9                             JIMIN
# 65       83         83   9                                지민
# 66       75         75   9                              GOT7
# 67       72         71   9                                 뷔
# 68       70         68   9                                 V
# 69       69         69   9                              BTSV
# 70       67         66   9                          TAEHYUNG
# 71       63         62   9                           NAMJOON
# 72       62         61   9                               김남준
# 73       60         53   9                         redvelvet
# 74       59         33   9              50DaysToAVPLEuphoria
# 75       55         55   9                      SEAGames2019
# 76       54         54   9                                남준
# 77       52         43   9          ABeautifuLAYFirstConcert
# 78       52         52   9                                알엠
# 79       51         48   9                WonhoIsOurStrength
# 80      503        428  10                               BTS
# 81      375        369  10                             방탄소년단
# 82      355        309  10               LaRougeInSeoul_Day2
# 83      193        178  10                          MAMAVOTE
# 84      174        173  10                          JUNGKOOK
# 85      169        168  10                                정국
# 86      144        140  10                               EXO
# 87      120        120  10                                태형
# 88      115        115  10                                 진
# 89      112        112  10                               JIN
# 90      106        104  10             District9_Unlock_Day2
# 91      102        102  10                               김석진
# 92       96         96  10                                엑소
# 93       95         95  10                                 뷔
# 94       93         79  10      The2wishEverlastingLoveinBkk
# 95       90         90  10                                 V
# 96       88         88  10                          TAEHYUNG
# 97       80         80  10                            방탄소년단진
# 98       79         79  10                              BTSV
# 99       76         66  10          ABeautifuLAYFirstConcert
# 100      74         74  10                             JIMIN
# 101      70         63  10                         redvelvet
# 102      68         66  10                    MagicShopJapan
# 103      68         68  10                         MAGICSHOP
# 104      65         65  10                    magicshopchiba
# 105      64         64  10                                RM
# 106      62         62  10                                지민
# 107      59         57  10                         RedVelvet
# 108      54         53  10                              GOT7
# 109     435        367  11                               BTS
# 110     330        323  11                             방탄소년단
# 111     288        284  11                                태형
# 112     274        270  11                                 뷔
# 113     244        241  11                          TAEHYUNG
# 114     227        224  11                                 V
# 115     222        218  11                              BTSV
# 116     220        216  11                            방탄소년단뷔
# 117     161        150  11               LaRougeInSeoul_Day2
# 118     123        116  11                            스트레이키즈
# 119     120         43  11              50DaysToAVPLEuphoria
# 120     118        117  11                                정국
# 121     116        115  11                          JUNGKOOK
# 122     109        106  11                          MAMAVOTE
# 123     104         98  11                               EXO
# 124     100         99  11                             JIMIN
# 125      95         94  11                                지민
# 126      94         90  11                         StrayKids
# 127      93         90  11                                 진
# 128      88         86  11                               김석진
# 129      88         85  11                               JIN
# 130      67         64  11             District9_Unlock_Day2
# 131      66         64  11                            방탄소년단진
# 132      65         64  11                           GooHara
# 133      64         63  11                                엑소
# 134      61         57  11                       ChummaKizhi
# 135      59         58  11                    magicshopchiba
# 136      58         57  11                         MAGICSHOP
# 137      54         44  11      The2wishEverlastingLoveinBkk
# 138      54         52  11                              GOT7
# 139      52         51  11                               옹성우
# 140     537        358  12           தமிழகத்தின்தலைமகன்அஜித்
# 141     530        376  12        GloriousThalapathyVIJAYEra
# 142     395        344  12                               BTS
# 143     267        265  12                             방탄소년단
# 144     261        225  12                             Bigil
# 145     233        232  12                                태형
# 146     228        227  12                                 뷔
# 147     208        207  12                          TAEHYUNG
# 148     200        198  12                                 V
# 149     177        176  12                            방탄소년단뷔
# 150     176        175  12                              BTSV
# 151     172        159  12                            스트레이키즈
# 152     168         72  12              50DaysToAVPLEuphoria
# 153     133        122  12                           Valimai
# 154     131        124  12                         StrayKids
# 155     118        116  12                               JIN
# 156     117        106  12                          Viswasam
# 157     114        112  12                                 진
# 158     112        112  12                          JUNGKOOK
# 159     109        109  12                                정국
# 160     107        105  12                               김석진
# 161     106        103  12                       ChummaKizhi
# 162     103         97  12                          MAMAVOTE
# 163      87         81  12                        Thalapathy
# 164      72         70  12               LaRougeInSeoul_Day2
# 165      71         68  12                               EXO
# 166      69         64  12                            Darbar
# 167      67         65  12                             BIGIL
# 168      56         56  12                             JIMIN
# 169      55         53  12                             Vijay
# 170      54         36  12             justice_binsachivalay
# 171      53         44  12                 YourMomentMalupet
# 172      53         52  12                     SS8inBKK_Day2
# 173     808        535  13           தமிழகத்தின்தலைமகன்அஜித்
# 174     751        560  13        GloriousThalapathyVIJAYEra
# 175     491        414  13                             Bigil
# 176     414        354  13                               BTS
# 177     307        302  13                             방탄소년단
# 178     195        194  13                                태형
# 179     171        171  13                                 V
# 180     160        159  13                                 뷔
# 181     149        141  13                          Viswasam
# 182     145        136  13                           Valimai
# 183     143        142  13                          TAEHYUNG
# 184     137        129  13                             BIGIL
# 185     122        122  13                              BTSV
# 186     121        119  13                             JIMIN
# 187     119        119  13                            방탄소년단뷔
# 188     114        110  13                            스트레이키즈
# 189     111        109  13                                지민
# 190     110        106  13                                정국
# 191     108        105  13                          JUNGKOOK
# 192     100         97  13                               JIN
# 193      98         95  13                                 진
# 194      95         91  13                         StrayKids
# 195      85         79  13                          MAMAVOTE
# 196      84         82  13                               김석진
# 197      76         58  13             justice_binsachivalay
# 198      74         72  13                             Thala
# 199      73         68  13                       ChummaKizhi
# 200      71         68  13                              레드벨벳
# 201      69         69  13                               EXO
# 202      61         60  13                        Thalapathy
# 203      56         40  13                        ThalaAjith
# 204      53         53  13                            방탄소년단진
# 205      53         52  13        GloriousThalapathyVijayEra
# 206      51         50  13                              GOT7
# 207     497        398  14        GloriousThalapathyVIJAYEra
# 208     496        363  14           தமிழகத்தின்தலைமகன்அஜித்
# 209     353        304  14                             Bigil
# 210     324        278  14                               BTS
# 211     245        238  14                             방탄소년단
# 212     138        137  14                                태형
# 213     118        109  14                          Viswasam
# 214     112        111  14                                 뷔
# 215     111        110  14                                 V
# 216     109        103  14                             BIGIL
# 217     105        104  14                          JUNGKOOK
# 218     105        104  14                                정국
# 219      95         95  14                             JIMIN
# 220      94         93  14                          TAEHYUNG
# 221      90         88  14                            스트레이키즈
# 222      86         86  14                                지민
# 223      86         86  14                            방탄소년단뷔
# 224      84         83  14                             Thala
# 225      84         76  14                           Valimai
# 226      80         80  14                              BTSV
# 227      79         78  14                         StrayKids
# 228      78         77  14                          MAMAVOTE
# 229      74         73  14                               JIN
# 230      69         69  14                                 진
# 231      69         57  14               LoveByChanceSeason2
# 232      68         67  14                               김석진
# 233      66         64  14                               EXO
# 234      56         56  14                           Frozen2
# 235      53         46  14             justice_binsachivalay
# 236      52         47  14                             AB6IX
# 237     523        407  15        GloriousThalapathyVIJAYEra
# 238     478        367  15           தமிழகத்தின்தலைமகன்அஜித்
# 239     427        361  15                             Bigil
# 240     265        243  15                               BTS
# 241     174        170  15                             방탄소년단
# 242     125        123  15                                태형
# 243     114        112  15                                 뷔
# 244     107        105  15                          TAEHYUNG
# 245     104         95  15                          Viswasam
# 246      99         97  15                          MAMAVOTE
# 247      98         96  15                                 V
# 248      96         95  15                                정국
# 249      96         95  15                          JUNGKOOK
# 250      93         91  15                              BTSV
# 251      91         75  15                           Valimai
# 252      79         78  15                             BIGIL
# 253      76         74  15                            방탄소년단뷔
# 254      61         47  15                 सुख_का_सागर_सतलोक
# 255      58         50  15               LoveByChanceSeason2
# 256      57         57  15           MyFirstParentingMistake
# 257      57         55  15                             Thala
# 258      55         55  15                             JIMIN
# 259      54         52  15                          JESC2019
# 260      53         53  15                              MUFC
# 261      53         52  15                              GOT7
# 262      52         51  15                                 진
# 263      52         48  15        GloriousThalapathyVijayEra
# 264      51         51  15                           Frozen2
# 265     607        466  16        GloriousThalapathyVIJAYEra
# 266     573        406  16           தமிழகத்தின்தலைமகன்அஜித்
# 267     407        331  16                             Bigil
# 268     196        178  16                               BTS
# 269     150        146  16                             방탄소년단
# 270     117        106  16                          Viswasam
# 271     112        100  16                           Valimai
# 272     102         98  16                             BIGIL
# 273      88         87  16                      DateMyFamily
# 274      84         83  16                            SHUMUN
# 275      79         77  16                                태형
# 276      77         77  16                          JUNGKOOK
# 277      76         76  16                                정국
# 278      72         70  16                          MAMAVOTE
# 279      69         67  16                                 뷔
# 280      62         60  16                          TAEHYUNG
# 281      62         60  16                                 V
# 282      56         55  16                             Thala
# 283      55         53  16                            스트레이키즈
# 284      54         54  16           MyFirstParentingMistake
# 285      53         52  16                              BTSV
# 286      52         49  16                         StrayKids
# 287      51         50  16                   என்றும்_தலஅஜித்
# 288     591        442  17        GloriousThalapathyVIJAYEra
# 289     425        315  17           தமிழகத்தின்தலைமகன்அஜித்
# 290     407        324  17                             Bigil
# 291     230        228  17                            SHUMUN
# 292     137        125  17                               BTS
# 293     100         97  17                             방탄소년단
# 294      92         91  17                              MUFC
# 295      64         64  17           MyFirstParentingMistake
# 296      61         60  17                                태형
# 297      57         53  17                          Viswasam
# 298      53         50  17                           Valimai
# 299      52         51  17                                 뷔
# 300      52         50  17                          JUNGKOOK
# 301      51         50  17                                정국
# 302      51         51  17                           Frozen2
# 303     456        340  18        GloriousThalapathyVIJAYEra
# 304     326        323  18                            SHUMUN
# 305     283        231  18                             Bigil
# 306     269        206  18           தமிழகத்தின்தலைமகன்அஜித்
# 307     209        204  18                   GOATBlackFriday
# 308     151        147  18                              MUFC
# 309     107         93  18                               BTS
# 310      69         56  18                            OleOut
# 311      66         66  18                             방탄소년단
# 312      52         52  18           MyFirstParentingMistake
# 313     124         84  19           தமிழகத்தின்தலைமகன்அஜித்
# 314     113        108  19                   GOATBlackFriday
# 315      88         77  19        GloriousThalapathyVIJAYEra
# 316      78         75  19                               BTS
# 317      66         65  19                              AMAs
# 318      66         59  19                             Bigil
# 319      59         59  19                            SHUMUN
# 320      93         88  20                   GOATBlackFriday
# 321      57         57  20                              AMAs
# 322      54         53  20                               BTS
# 323      51         36  20           தமிழகத்தின்தலைமகன்அஜித்
# 324     108        107  21                          ImACeleb
# 325      92         85  21                               BTS
# 326      88         88  21                              AMAs
# 327      78         69  21                          MAMAVOTE
# 328      59         59  21                           DALvsNE
# 329      59         58  21                   GOATBlackFriday
# 330     113        112  22                          ImACeleb
# 331     112        112  22                              AMAs
# 332     105         96  22                               BTS
# 333     104         99  22                  LivingProofVideo
# 334      82         81  22                    SurvivorSeries
# 335      66         64  22                             방탄소년단
# 336      61         60  22                          MAMAVOTE
# 337      59         59  22                           DALvsNE
# 338      58         56  22                   GOATBlackFriday
